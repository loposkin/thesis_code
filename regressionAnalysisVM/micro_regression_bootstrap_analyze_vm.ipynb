# %%
import pandas as pd
import random
import numpy as np
from numpy.random import default_rng
import seaborn as sns
from statistics import median
import os
from os import path
sns.set()
rng = default_rng()

# %%
numberOfSamples = 10000
filename = "microbenchRegressionAll.csv"
outFolderName = "bootstrapping_" + str(numberOfSamples)

debug = False
# iterations of microbenchmarks
numberOfIterations = 5
CIsmall = 1
CImed = 5
CIlarge = 10

# %%
! mkdir -p {outFolderName} # type: ignore

# %%
def resample(perfRuntimes1: pd.DataFrame, 
            perfRuntimes2: pd.DataFrame, 
            instanceRuns: np.ndarray, 
            suiteRuns: np.ndarray,
            numberOfIterations: int,
            numberOfSamples: int) -> np.ndarray:
    """
        Resamples performances using hierarchical bootstrapping for building confindence intervals

        Builds a tensor of random indices of a form numberOfSamples * instanceRunsNumber * suiteRunsNumber * numberOfIterations.
        Then uses these indices to choose from a performance runtimes tensor with a form instanceRunsNumber * suiteRunsNumber * numberOfIterations.
        Finally, reshapes resulting tensor to a matrix of form numberOfSamples * ( instanceRunsNumber * suiteRunsNumber * numberOfIterations)
        and calculates performance differences between medians.

        Parameters
        ----------
        perfRuntimes1 : performance runtimes of the first version.
        perfRuntimes2 : performance runtimes of the second version.
        instanceRuns : array of instanceRun numbers
        suiteRuns : array of suiteRun numbers
        numberOfIterations : number of microbenchmark iterations

        Returns
        -------
        np.ndarray
            array of performance differences with a shape numberOfSample * 1.

        """
    instanceRunsNumber = instanceRuns.shape[0]
    suiteRunsNumber = suiteRuns.shape[0]

    allRuntimes1 = np.ndarray((instanceRunsNumber, suiteRunsNumber, numberOfIterations))
    allRuntimes2 = np.ndarray((instanceRunsNumber, suiteRunsNumber, numberOfIterations))
    

    for instanceRun in instanceRuns:
        for suiteRun in suiteRuns:
            allRuntimes1[instanceRun - 1][suiteRun] = perfRuntimes1.loc[(perfRuntimes1['instanceRun'] == instanceRun)
                                                    & (perfRuntimes1['suiteRun'] == suiteRun),
                                                    'runtime'].to_numpy()
            allRuntimes2[instanceRun - 1][suiteRun] = perfRuntimes2.loc[(perfRuntimes2['instanceRun'] == instanceRun)
                                                    & (perfRuntimes2['suiteRun'] == suiteRun),
                                                    'runtime'].to_numpy()

    currentInstanceRun = rng.choice(instanceRuns, size=(instanceRunsNumber, numberOfSamples)) - 1
    currentSuiteRun = rng.choice(suiteRuns, size=(suiteRunsNumber, instanceRunsNumber, numberOfSamples))
    currentRuntimes1 = rng.integers(numberOfIterations, size=(numberOfIterations, suiteRunsNumber, instanceRunsNumber, numberOfSamples))
    currentRuntimes2 = rng.integers(numberOfIterations, size=(numberOfIterations, suiteRunsNumber, instanceRunsNumber, numberOfSamples))

    tmp1 = allRuntimes1[currentInstanceRun, currentSuiteRun, currentRuntimes1]
    tmp1 = np.stack(tmp1, axis=3).reshape((numberOfSamples, suiteRunsNumber * instanceRunsNumber * numberOfIterations))

    tmp2 = allRuntimes2[currentInstanceRun, currentSuiteRun, currentRuntimes2]
    tmp2 = np.stack(tmp2, axis=3).reshape((numberOfSamples, suiteRunsNumber * instanceRunsNumber * numberOfIterations))
    # Get median for both lists
    med1 = np.median(tmp1, axis=1)
    med2 = np.median(tmp2, axis=1)
    
    return med2/med1

# %%
df_all = pd.read_csv(filename,sep=";")


# For each microbenchmark
for name in df_all.name.unique():
    print(f"Running analysis for benchmark {name}...")

    benchmarkMeasurements = df_all.loc[(df_all['name'].str.startswith(name, na=False))]

    instanceRuns = benchmarkMeasurements.instanceRun.unique()
    suiteRuns = benchmarkMeasurements.suiteRun.unique()


    if len(benchmarkMeasurements) > 300:
        printName = name.replace("/","-")
        printName = printName.replace("/","-")
        benchmarkFilename = os.path.join(outFolderName, printName + ".csv")
        if path.exists(benchmarkFilename):
            print("  Already analyzed, skip.")
        else:
            results = []
            # For each commit (number)
            for commitNumber in benchmarkMeasurements.number.unique():
                print(f"  Running analysis for commit {commitNumber}...")

                #Find median perf. change
                perfRuntimes1 = benchmarkMeasurements.loc[(benchmarkMeasurements['number'] == commitNumber)
                                                    & (benchmarkMeasurements['version'] == 1)]
                perfRuntimes2 = benchmarkMeasurements.loc[(benchmarkMeasurements['number'] == commitNumber)
                                                    & (benchmarkMeasurements['version'] == 2)]
                

                elements1 = perfRuntimes1['runtime'].shape[0]
                elements2 = perfRuntimes2['runtime'].shape[0]
                if (elements1 == 45) & (elements2 == 45):

                    perf1 = perfRuntimes1['runtime'].median()
                    perf2 = perfRuntimes2['runtime'].median()
                    # Compare both (e.g., 10ms in ver1 and 12ms in ver2 => 12/10 = 1.2 (>1 -> regression)
                    perfChange = ((perf2/perf1) - 1) * 100

                    print(f"    Found median performance change ({perfChange}).")

                    # Run Bootstrapping
                    # R stores the 10.000 median values
                    R = resample(perfRuntimes1=perfRuntimes1, 
                            perfRuntimes2=perfRuntimes2, 
                            instanceRuns=instanceRuns, 
                            suiteRuns=suiteRuns,
                            numberOfIterations=numberOfIterations,
                            numberOfSamples=numberOfSamples)

                    print(f"    Bootstrapping done ({len(R)} elements in R).")

                    # Find conf. intervals
                    R.sort()

                    small = int((numberOfSamples * CIsmall) / 100 / 2)
                    if small == 0:
                        small  = 1
                    medium = int((numberOfSamples * CImed) / 100 / 2)
                    large = int((numberOfSamples * CIlarge) / 100 / 2)

                    minSmall = R[small-1]
                    minSmall = (minSmall - 1) * 100
                    maxSmall = R[numberOfSamples-small-1]
                    maxSmall = (maxSmall - 1) * 100

                    minMedium = R[medium-1]
                    minMedium = (minMedium - 1) * 100
                    maxMedium = R[numberOfSamples-medium-1]
                    maxMedium = (maxMedium - 1) * 100

                    minLarge = R[large-1]
                    minLarge = (minLarge - 1) * 100
                    maxLarge = R[numberOfSamples-large-1]
                    maxLarge = (maxLarge - 1) * 100

                    print(f"    Found conf. intervals ([{minSmall}, {maxSmall}],[{minMedium}, {maxMedium}],[{minLarge}, {maxLarge}]).")

                    #Store values
                    results.append({
                                    "name" : name,
                                    "number" : int(commitNumber),
                                    "medianPerfChange" : perfChange,
                                    "minSmall" : minSmall,
                                    "maxSmall" : maxSmall,
                                    "minMedium" :minMedium,
                                    "maxMedium" : maxMedium,
                                    "minLarge" : minLarge,
                                    "maxLarge" : maxLarge,
                                    })
                    print("    Values stored.")
                else:
                    print(f"  Skip {name};{commitNumber}, only ({elements1}, {elements2}) elements.")

            #Store results for this benchmark to file
            # Convert to data frame
            df_results = pd.DataFrame(results)
            if len(results) > 0:
                df_results.sort_values(by=["name","number"], inplace=True)
                df_results.describe()

                #Create folder
                #Save file
                df_results.to_csv(benchmarkFilename, sep=";")

    else:
        print(f"  Skip {name}, only {len(benchmarkMeasurements)} measurments.")
# Out:
# Running analysis for benchmark BenchmarkAdd/items_1000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkAdd/items_10000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkAdd/items_100000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkAdd/items_1000000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkAdd/items_10000000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkAddMulti/items_1000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkAddMulti/items_10000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkAddMulti/items_100000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkAddMulti/items_1000000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkAddMulti/items_10000000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkAppendDecimalToFloat/Integers-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkAppendDecimalToFloat/Ones-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkAppendDecimalToFloat/RealFloat-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkAppendDecimalToFloat/Zeros-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkAppendFloatToDecimal/Integers-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkAppendFloatToDecimal/Ones-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkAppendFloatToDecimal/RealFloat-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkAppendFloatToDecimal/Zeros-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkBlockStreamReaderBlocksBestCase-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkBlockStreamReaderBlocksWorstCase-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkBlockStreamReaderRowsBestCase-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkBlockStreamReaderRowsWorstCase-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkBlockStreamWriterBlocksBestCase-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkBlockStreamWriterBlocksWorstCase-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkBlockStreamWriterRowsBestCase-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkBlockStreamWriterRowsWorstCase-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkDeduplicateSamples/minScrapeInterval=10s-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkDeduplicateSamples/minScrapeInterval=1s-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkDeduplicateSamples/minScrapeInterval=2s-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkDeduplicateSamples/minScrapeInterval=5s-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkFromFloat/0-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkFromFloat/1.2334345e+07-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkFromFloat/1.23454435e+31-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkFromFloat/1.2345678901e+14-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkFromFloat/1234-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkFromFloat/12343.4344-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkInmemoryBlockMarshal-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkInmemoryBlockUnmarshal-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkInmemoryPartInitFromRowsBestCase-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkInmemoryPartInitFromRowsWorstCase-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkIntersectFullOverlap/items_1000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkIntersectFullOverlap/items_10000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkIntersectFullOverlap/items_100000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkIntersectFullOverlap/items_1000000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkIntersectFullOverlap/items_10000000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkIntersectNoOverlap/items_1000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkIntersectNoOverlap/items_10000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkIntersectNoOverlap/items_100000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkIntersectNoOverlap/items_1000000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkIntersectNoOverlap/items_10000000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkIntersectPartialOverlap/items_1000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkIntersectPartialOverlap/items_10000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkIntersectPartialOverlap/items_100000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkIntersectPartialOverlap/items_1000000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkIntersectPartialOverlap/items_10000000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMapAddNoAllocs/items_1000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMapAddNoAllocs/items_10000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMapAddNoAllocs/items_100000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMapAddNoAllocs/items_1000000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMapAddNoAllocs/items_10000000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMapAddRandomLastBits/lastBits_20-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMapAddRandomLastBits/lastBits_24-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMapAddRandomLastBits/lastBits_28-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMapAddRandomLastBits/lastBits_32-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMapAddReuse/items_1000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMapAddReuse/items_10000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMapAddReuse/items_100000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMapAddReuse/items_1000000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMapAddReuse/items_10000000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMapAddWithAllocs/items_1000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMapAddWithAllocs/items_10000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMapAddWithAllocs/items_100000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMapAddWithAllocs/items_1000000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMapAddWithAllocs/items_10000000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMapHasHit/items_1000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMapHasHit/items_10000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMapHasHit/items_100000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMapHasHit/items_1000000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMapHasHit/items_10000000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMapHasMiss/items_1000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMapHasMiss/items_10000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMapHasMiss/items_100000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMapHasMiss/items_1000000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMapHasMiss/items_10000000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMarshalConstArray-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMarshalDeltaConstArray-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMarshalGaugeArray-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMarshalInt64-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMarshalInt64Array-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMarshalInt64NearestDelta/precisionBits_4-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMarshalInt64NearestDelta/precisionBits_64-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMarshalInt64NearestDelta2/precisionBits_4-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMarshalInt64NearestDelta2/precisionBits_64-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMarshalUint64-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMarshalVarInt64s/up-to-(1<<13)-1-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMarshalVarInt64s/up-to-(1<<27)-1-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMarshalVarInt64s/up-to-(1<<6)-1-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMarshalVarInt64s/up-to-(1<<63)-1-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMarshalZeroConstArray-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMergeBlockStreamsFourSourcesBestCase-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMergeBlockStreamsFourSourcesWorstCase-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMergeBlockStreamsTwoSourcesBestCase-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkMergeBlockStreamsTwoSourcesWorstCase-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkRegexpFilterMatch-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkRegexpFilterMismatch-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkRollupAvg-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkRowsUnmarshal-2...
#   Running analysis for commit 1...
#   Skip BenchmarkRowsUnmarshal-2;1, only (315, 315) elements.
#   Running analysis for commit 11...
#   Skip BenchmarkRowsUnmarshal-2;11, only (315, 315) elements.
#   Running analysis for commit 16...
#   Skip BenchmarkRowsUnmarshal-2;16, only (315, 315) elements.
#   Running analysis for commit 21...
#   Skip BenchmarkRowsUnmarshal-2;21, only (315, 315) elements.
#   Running analysis for commit 26...
#   Skip BenchmarkRowsUnmarshal-2;26, only (315, 315) elements.
#   Running analysis for commit 31...
#   Skip BenchmarkRowsUnmarshal-2;31, only (315, 315) elements.
#   Running analysis for commit 36...
#   Skip BenchmarkRowsUnmarshal-2;36, only (315, 315) elements.
#   Running analysis for commit 41...
#   Skip BenchmarkRowsUnmarshal-2;41, only (315, 315) elements.
#   Running analysis for commit 46...
#   Skip BenchmarkRowsUnmarshal-2;46, only (315, 315) elements.
#   Running analysis for commit 51...
#   Skip BenchmarkRowsUnmarshal-2;51, only (315, 315) elements.
#   Running analysis for commit 56...
#   Skip BenchmarkRowsUnmarshal-2;56, only (315, 315) elements.
#   Running analysis for commit 6...
#   Skip BenchmarkRowsUnmarshal-2;6, only (315, 315) elements.
#   Running analysis for commit 61...
#   Skip BenchmarkRowsUnmarshal-2;61, only (315, 315) elements.
#   Running analysis for commit 66...
#   Skip BenchmarkRowsUnmarshal-2;66, only (315, 315) elements.
# Running analysis for benchmark BenchmarkScrapeWorkScrapeInternal-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkSetAddRandomLastBits/lastBits_20-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkSetAddRandomLastBits/lastBits_24-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkSetAddRandomLastBits/lastBits_28-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkSetAddRandomLastBits/lastBits_32-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkSetAddWithAllocs/items_1000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkSetAddWithAllocs/items_10000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkSetAddWithAllocs/items_100000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkSetAddWithAllocs/items_1000000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkSetAddWithAllocs/items_10000000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkSetHasHit/items_1000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkSetHasHit/items_10000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkSetHasHit/items_100000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkSetHasHit/items_1000000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkSetHasHit/items_10000000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkSetHasMiss/items_1000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkSetHasMiss/items_10000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkSetHasMiss/items_100000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkSetHasMiss/items_1000000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkSetHasMiss/items_10000000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkStorageAddRows1...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkStorageAddRows2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkStorageAddRows3...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkStorageAddRows4...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkTimeNowUnix-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkUnionFullOverlap/items_1000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkUnionFullOverlap/items_10000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkUnionFullOverlap/items_100000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkUnionFullOverlap/items_1000000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkUnionFullOverlap/items_10000000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkUnionNoOverlap/items_1000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkUnionNoOverlap/items_10000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkUnionNoOverlap/items_100000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkUnionNoOverlap/items_1000000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkUnionNoOverlap/items_10000000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkUnionPartialOverlap/items_1000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkUnionPartialOverlap/items_10000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkUnionPartialOverlap/items_100000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkUnionPartialOverlap/items_1000000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkUnionPartialOverlap/items_10000000-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkUnixTimestamp-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkUnmarshalConstArray-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkUnmarshalDeltaConstArray-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkUnmarshalGaugeArray-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkUnmarshalInt64-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkUnmarshalInt64Array-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkUnmarshalInt64NearestDelta-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkUnmarshalInt64NearestDelta2-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkUnmarshalUint64-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkUnmarshalVarInt64s/up-to-(1<<13)-1-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkUnmarshalVarInt64s/up-to-(1<<27)-1-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkUnmarshalVarInt64s/up-to-(1<<6)-1-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkUnmarshalVarInt64s/up-to-(1<<63)-1-2...
#   Already analyzed, skip.
# Running analysis for benchmark BenchmarkUnmarshalZeroConstArray-2...
#   Already analyzed, skip.
# Running analysis for benchmark bench-fast-queue-throughput-concurrent-1...
#   Running analysis for commit 1...
#   Skip bench-fast-queue-throughput-concurrent-1;1, only (315, 315) elements.
#   Running analysis for commit 11...
#   Skip bench-fast-queue-throughput-concurrent-1;11, only (315, 315) elements.
#   Running analysis for commit 16...
#   Skip bench-fast-queue-throughput-concurrent-1;16, only (315, 315) elements.
#   Running analysis for commit 21...
#   Skip bench-fast-queue-throughput-concurrent-1;21, only (315, 315) elements.
#   Running analysis for commit 26...
#   Skip bench-fast-queue-throughput-concurrent-1;26, only (315, 315) elements.
#   Running analysis for commit 31...
#   Skip bench-fast-queue-throughput-concurrent-1;31, only (315, 315) elements.
#   Running analysis for commit 36...
#   Skip bench-fast-queue-throughput-concurrent-1;36, only (315, 315) elements.
#   Running analysis for commit 41...
#   Skip bench-fast-queue-throughput-concurrent-1;41, only (315, 315) elements.
#   Running analysis for commit 46...
#   Skip bench-fast-queue-throughput-concurrent-1;46, only (315, 315) elements.
#   Running analysis for commit 51...
#   Skip bench-fast-queue-throughput-concurrent-1;51, only (315, 315) elements.
#   Running analysis for commit 56...
#   Skip bench-fast-queue-throughput-concurrent-1;56, only (315, 315) elements.
#   Running analysis for commit 6...
#   Skip bench-fast-queue-throughput-concurrent-1;6, only (315, 315) elements.
#   Running analysis for commit 61...
#   Skip bench-fast-queue-throughput-concurrent-1;61, only (315, 315) elements.
#   Running analysis for commit 66...
#   Skip bench-fast-queue-throughput-concurrent-1;66, only (315, 315) elements.
# Running analysis for benchmark bench-fast-queue-throughput-concurrent-10...
#   Running analysis for commit 1...
#   Skip bench-fast-queue-throughput-concurrent-10;1, only (270, 270) elements.
#   Running analysis for commit 11...
#   Skip bench-fast-queue-throughput-concurrent-10;11, only (270, 270) elements.
#   Running analysis for commit 16...
#   Skip bench-fast-queue-throughput-concurrent-10;16, only (270, 270) elements.
#   Running analysis for commit 21...
#   Skip bench-fast-queue-throughput-concurrent-10;21, only (270, 270) elements.
#   Running analysis for commit 26...
#   Skip bench-fast-queue-throughput-concurrent-10;26, only (270, 270) elements.
#   Running analysis for commit 31...
#   Skip bench-fast-queue-throughput-concurrent-10;31, only (270, 270) elements.
#   Running analysis for commit 36...
#   Skip bench-fast-queue-throughput-concurrent-10;36, only (270, 270) elements.
#   Running analysis for commit 41...
#   Skip bench-fast-queue-throughput-concurrent-10;41, only (270, 270) elements.
#   Running analysis for commit 46...
#   Skip bench-fast-queue-throughput-concurrent-10;46, only (270, 270) elements.
#   Running analysis for commit 51...
#   Skip bench-fast-queue-throughput-concurrent-10;51, only (270, 270) elements.
#   Running analysis for commit 56...
#   Skip bench-fast-queue-throughput-concurrent-10;56, only (270, 270) elements.
#   Running analysis for commit 6...
#   Skip bench-fast-queue-throughput-concurrent-10;6, only (270, 270) elements.
#   Running analysis for commit 61...
#   Skip bench-fast-queue-throughput-concurrent-10;61, only (270, 270) elements.
#   Running analysis for commit 66...
#   Skip bench-fast-queue-throughput-concurrent-10;66, only (270, 270) elements.
# Running analysis for benchmark bench-fast-queue-throughput-concurrent-100...
#   Running analysis for commit 1...
#   Skip bench-fast-queue-throughput-concurrent-100;1, only (225, 225) elements.
#   Running analysis for commit 11...
#   Skip bench-fast-queue-throughput-concurrent-100;11, only (225, 225) elements.
#   Running analysis for commit 16...
#   Skip bench-fast-queue-throughput-concurrent-100;16, only (225, 225) elements.
#   Running analysis for commit 21...
#   Skip bench-fast-queue-throughput-concurrent-100;21, only (225, 225) elements.
#   Running analysis for commit 26...
#   Skip bench-fast-queue-throughput-concurrent-100;26, only (225, 225) elements.
#   Running analysis for commit 31...
#   Skip bench-fast-queue-throughput-concurrent-100;31, only (225, 225) elements.
#   Running analysis for commit 36...
#   Skip bench-fast-queue-throughput-concurrent-100;36, only (225, 225) elements.
#   Running analysis for commit 41...
#   Skip bench-fast-queue-throughput-concurrent-100;41, only (225, 225) elements.
#   Running analysis for commit 46...
#   Skip bench-fast-queue-throughput-concurrent-100;46, only (225, 225) elements.
#   Running analysis for commit 51...
#   Skip bench-fast-queue-throughput-concurrent-100;51, only (225, 225) elements.
#   Running analysis for commit 56...
#   Skip bench-fast-queue-throughput-concurrent-100;56, only (225, 225) elements.
#   Running analysis for commit 6...
#   Skip bench-fast-queue-throughput-concurrent-100;6, only (225, 225) elements.
#   Running analysis for commit 61...
#   Skip bench-fast-queue-throughput-concurrent-100;61, only (225, 225) elements.
#   Running analysis for commit 66...
#   Skip bench-fast-queue-throughput-concurrent-100;66, only (225, 225) elements.
# Running analysis for benchmark bench-fast-queue-throughput-concurrent-1000...
#   Running analysis for commit 1...
#   Skip bench-fast-queue-throughput-concurrent-1000;1, only (180, 180) elements.
#   Running analysis for commit 11...
#   Skip bench-fast-queue-throughput-concurrent-1000;11, only (180, 180) elements.
#   Running analysis for commit 16...
#   Skip bench-fast-queue-throughput-concurrent-1000;16, only (180, 180) elements.
#   Running analysis for commit 21...
#   Skip bench-fast-queue-throughput-concurrent-1000;21, only (180, 180) elements.
#   Running analysis for commit 26...
#   Skip bench-fast-queue-throughput-concurrent-1000;26, only (180, 180) elements.
#   Running analysis for commit 31...
#   Skip bench-fast-queue-throughput-concurrent-1000;31, only (180, 180) elements.
#   Running analysis for commit 36...
#   Skip bench-fast-queue-throughput-concurrent-1000;36, only (180, 180) elements.
#   Running analysis for commit 41...
#   Skip bench-fast-queue-throughput-concurrent-1000;41, only (180, 180) elements.
#   Running analysis for commit 46...
#   Skip bench-fast-queue-throughput-concurrent-1000;46, only (180, 180) elements.
#   Running analysis for commit 51...
#   Skip bench-fast-queue-throughput-concurrent-1000;51, only (180, 180) elements.
#   Running analysis for commit 56...
#   Skip bench-fast-queue-throughput-concurrent-1000;56, only (180, 180) elements.
#   Running analysis for commit 6...
#   Skip bench-fast-queue-throughput-concurrent-1000;6, only (180, 180) elements.
#   Running analysis for commit 61...
#   Skip bench-fast-queue-throughput-concurrent-1000;61, only (180, 180) elements.
#   Running analysis for commit 66...
#   Skip bench-fast-queue-throughput-concurrent-1000;66, only (180, 180) elements.
# Running analysis for benchmark bench-fast-queue-throughput-concurrent-10000...
#   Running analysis for commit 1...
#   Skip bench-fast-queue-throughput-concurrent-10000;1, only (135, 135) elements.
#   Running analysis for commit 11...
#   Skip bench-fast-queue-throughput-concurrent-10000;11, only (135, 135) elements.
#   Running analysis for commit 16...
#   Skip bench-fast-queue-throughput-concurrent-10000;16, only (135, 135) elements.
#   Running analysis for commit 21...
#   Skip bench-fast-queue-throughput-concurrent-10000;21, only (135, 135) elements.
#   Running analysis for commit 26...
#   Skip bench-fast-queue-throughput-concurrent-10000;26, only (135, 135) elements.
#   Running analysis for commit 31...
#   Skip bench-fast-queue-throughput-concurrent-10000;31, only (135, 135) elements.
#   Running analysis for commit 36...
#   Skip bench-fast-queue-throughput-concurrent-10000;36, only (135, 135) elements.
#   Running analysis for commit 41...
#   Skip bench-fast-queue-throughput-concurrent-10000;41, only (135, 135) elements.
#   Running analysis for commit 46...
#   Skip bench-fast-queue-throughput-concurrent-10000;46, only (135, 135) elements.
#   Running analysis for commit 51...
#   Skip bench-fast-queue-throughput-concurrent-10000;51, only (135, 135) elements.
#   Running analysis for commit 56...
#   Skip bench-fast-queue-throughput-concurrent-10000;56, only (135, 135) elements.
#   Running analysis for commit 6...
#   Skip bench-fast-queue-throughput-concurrent-10000;6, only (135, 135) elements.
#   Running analysis for commit 61...
#   Skip bench-fast-queue-throughput-concurrent-10000;61, only (135, 135) elements.
#   Running analysis for commit 66...
#   Skip bench-fast-queue-throughput-concurrent-10000;66, only (135, 135) elements.
# Running analysis for benchmark bench-fast-queue-throughput-concurrent-100000...
#   Running analysis for commit 1...
#   Skip bench-fast-queue-throughput-concurrent-100000;1, only (90, 90) elements.
#   Running analysis for commit 11...
#   Skip bench-fast-queue-throughput-concurrent-100000;11, only (90, 90) elements.
#   Running analysis for commit 16...
#   Skip bench-fast-queue-throughput-concurrent-100000;16, only (90, 90) elements.
#   Running analysis for commit 21...
#   Skip bench-fast-queue-throughput-concurrent-100000;21, only (90, 90) elements.
#   Running analysis for commit 26...
#   Skip bench-fast-queue-throughput-concurrent-100000;26, only (90, 90) elements.
#   Running analysis for commit 31...
#   Skip bench-fast-queue-throughput-concurrent-100000;31, only (90, 90) elements.
#   Running analysis for commit 36...
#   Skip bench-fast-queue-throughput-concurrent-100000;36, only (90, 90) elements.
#   Running analysis for commit 41...
#   Skip bench-fast-queue-throughput-concurrent-100000;41, only (90, 90) elements.
#   Running analysis for commit 46...
#   Skip bench-fast-queue-throughput-concurrent-100000;46, only (90, 90) elements.
#   Running analysis for commit 51...
#   Skip bench-fast-queue-throughput-concurrent-100000;51, only (90, 90) elements.
#   Running analysis for commit 56...
#   Skip bench-fast-queue-throughput-concurrent-100000;56, only (90, 90) elements.
#   Running analysis for commit 6...
#   Skip bench-fast-queue-throughput-concurrent-100000;6, only (90, 90) elements.
#   Running analysis for commit 61...
#   Skip bench-fast-queue-throughput-concurrent-100000;61, only (90, 90) elements.
#   Running analysis for commit 66...
#   Skip bench-fast-queue-throughput-concurrent-100000;66, only (90, 90) elements.
# Running analysis for benchmark bench-fast-queue-throughput-concurrent-1000000...
#   Already analyzed, skip.
# Running analysis for benchmark bench-fast-queue-throughput-serial-1...
#   Running analysis for commit 1...
#   Skip bench-fast-queue-throughput-serial-1;1, only (315, 315) elements.
#   Running analysis for commit 11...
#   Skip bench-fast-queue-throughput-serial-1;11, only (315, 315) elements.
#   Running analysis for commit 16...
#   Skip bench-fast-queue-throughput-serial-1;16, only (315, 315) elements.
#   Running analysis for commit 21...
#   Skip bench-fast-queue-throughput-serial-1;21, only (315, 315) elements.
#   Running analysis for commit 26...
#   Skip bench-fast-queue-throughput-serial-1;26, only (315, 315) elements.
#   Running analysis for commit 31...
#   Skip bench-fast-queue-throughput-serial-1;31, only (315, 315) elements.
#   Running analysis for commit 36...
#   Skip bench-fast-queue-throughput-serial-1;36, only (315, 315) elements.
#   Running analysis for commit 41...
#   Skip bench-fast-queue-throughput-serial-1;41, only (315, 315) elements.
#   Running analysis for commit 46...
#   Skip bench-fast-queue-throughput-serial-1;46, only (315, 315) elements.
#   Running analysis for commit 51...
#   Skip bench-fast-queue-throughput-serial-1;51, only (315, 315) elements.
#   Running analysis for commit 56...
#   Skip bench-fast-queue-throughput-serial-1;56, only (315, 315) elements.
#   Running analysis for commit 6...
#   Skip bench-fast-queue-throughput-serial-1;6, only (315, 315) elements.
#   Running analysis for commit 61...
#   Skip bench-fast-queue-throughput-serial-1;61, only (315, 315) elements.
#   Running analysis for commit 66...
#   Skip bench-fast-queue-throughput-serial-1;66, only (315, 315) elements.
# Running analysis for benchmark bench-fast-queue-throughput-serial-10...
#   Running analysis for commit 1...
#   Skip bench-fast-queue-throughput-serial-10;1, only (270, 270) elements.
#   Running analysis for commit 11...
#   Skip bench-fast-queue-throughput-serial-10;11, only (270, 270) elements.
#   Running analysis for commit 16...
#   Skip bench-fast-queue-throughput-serial-10;16, only (270, 270) elements.
#   Running analysis for commit 21...
#   Skip bench-fast-queue-throughput-serial-10;21, only (270, 270) elements.
#   Running analysis for commit 26...
#   Skip bench-fast-queue-throughput-serial-10;26, only (270, 270) elements.
#   Running analysis for commit 31...
#   Skip bench-fast-queue-throughput-serial-10;31, only (270, 270) elements.
#   Running analysis for commit 36...
#   Skip bench-fast-queue-throughput-serial-10;36, only (270, 270) elements.
#   Running analysis for commit 41...
#   Skip bench-fast-queue-throughput-serial-10;41, only (270, 270) elements.
#   Running analysis for commit 46...
#   Skip bench-fast-queue-throughput-serial-10;46, only (270, 270) elements.
#   Running analysis for commit 51...
#   Skip bench-fast-queue-throughput-serial-10;51, only (270, 270) elements.
#   Running analysis for commit 56...
#   Skip bench-fast-queue-throughput-serial-10;56, only (270, 270) elements.
#   Running analysis for commit 6...
#   Skip bench-fast-queue-throughput-serial-10;6, only (270, 270) elements.
#   Running analysis for commit 61...
#   Skip bench-fast-queue-throughput-serial-10;61, only (270, 270) elements.
#   Running analysis for commit 66...
#   Skip bench-fast-queue-throughput-serial-10;66, only (270, 270) elements.
# Running analysis for benchmark bench-fast-queue-throughput-serial-100...
#   Running analysis for commit 1...
#   Skip bench-fast-queue-throughput-serial-100;1, only (225, 225) elements.
#   Running analysis for commit 11...
#   Skip bench-fast-queue-throughput-serial-100;11, only (225, 225) elements.
#   Running analysis for commit 16...
#   Skip bench-fast-queue-throughput-serial-100;16, only (225, 225) elements.
#   Running analysis for commit 21...
#   Skip bench-fast-queue-throughput-serial-100;21, only (225, 225) elements.
#   Running analysis for commit 26...
#   Skip bench-fast-queue-throughput-serial-100;26, only (225, 225) elements.
#   Running analysis for commit 31...
#   Skip bench-fast-queue-throughput-serial-100;31, only (225, 225) elements.
#   Running analysis for commit 36...
#   Skip bench-fast-queue-throughput-serial-100;36, only (225, 225) elements.
#   Running analysis for commit 41...
#   Skip bench-fast-queue-throughput-serial-100;41, only (225, 225) elements.
#   Running analysis for commit 46...
#   Skip bench-fast-queue-throughput-serial-100;46, only (225, 225) elements.
#   Running analysis for commit 51...
#   Skip bench-fast-queue-throughput-serial-100;51, only (225, 225) elements.
#   Running analysis for commit 56...
#   Skip bench-fast-queue-throughput-serial-100;56, only (225, 225) elements.
#   Running analysis for commit 6...
#   Skip bench-fast-queue-throughput-serial-100;6, only (225, 225) elements.
#   Running analysis for commit 61...
#   Skip bench-fast-queue-throughput-serial-100;61, only (225, 225) elements.
#   Running analysis for commit 66...
#   Skip bench-fast-queue-throughput-serial-100;66, only (225, 225) elements.
# Running analysis for benchmark bench-fast-queue-throughput-serial-1000...
#   Running analysis for commit 1...
#   Skip bench-fast-queue-throughput-serial-1000;1, only (180, 180) elements.
#   Running analysis for commit 11...
#   Skip bench-fast-queue-throughput-serial-1000;11, only (180, 180) elements.
#   Running analysis for commit 16...
#   Skip bench-fast-queue-throughput-serial-1000;16, only (180, 180) elements.
#   Running analysis for commit 21...
#   Skip bench-fast-queue-throughput-serial-1000;21, only (180, 180) elements.
#   Running analysis for commit 26...
#   Skip bench-fast-queue-throughput-serial-1000;26, only (180, 180) elements.
#   Running analysis for commit 31...
#   Skip bench-fast-queue-throughput-serial-1000;31, only (180, 180) elements.
#   Running analysis for commit 36...
#   Skip bench-fast-queue-throughput-serial-1000;36, only (180, 180) elements.
#   Running analysis for commit 41...
#   Skip bench-fast-queue-throughput-serial-1000;41, only (180, 180) elements.
#   Running analysis for commit 46...
#   Skip bench-fast-queue-throughput-serial-1000;46, only (180, 180) elements.
#   Running analysis for commit 51...
#   Skip bench-fast-queue-throughput-serial-1000;51, only (180, 180) elements.
#   Running analysis for commit 56...
#   Skip bench-fast-queue-throughput-serial-1000;56, only (180, 180) elements.
#   Running analysis for commit 6...
#   Skip bench-fast-queue-throughput-serial-1000;6, only (180, 180) elements.
#   Running analysis for commit 61...
#   Skip bench-fast-queue-throughput-serial-1000;61, only (180, 180) elements.
#   Running analysis for commit 66...
#   Skip bench-fast-queue-throughput-serial-1000;66, only (180, 180) elements.
# Running analysis for benchmark bench-fast-queue-throughput-serial-10000...
#   Running analysis for commit 1...
#   Skip bench-fast-queue-throughput-serial-10000;1, only (135, 135) elements.
#   Running analysis for commit 11...
#   Skip bench-fast-queue-throughput-serial-10000;11, only (135, 135) elements.
#   Running analysis for commit 16...
#   Skip bench-fast-queue-throughput-serial-10000;16, only (135, 135) elements.
#   Running analysis for commit 21...
#   Skip bench-fast-queue-throughput-serial-10000;21, only (135, 135) elements.
#   Running analysis for commit 26...
#   Skip bench-fast-queue-throughput-serial-10000;26, only (135, 135) elements.
#   Running analysis for commit 31...
#   Skip bench-fast-queue-throughput-serial-10000;31, only (135, 135) elements.
#   Running analysis for commit 36...
#   Skip bench-fast-queue-throughput-serial-10000;36, only (135, 135) elements.
#   Running analysis for commit 41...
#   Skip bench-fast-queue-throughput-serial-10000;41, only (135, 135) elements.
#   Running analysis for commit 46...
#   Skip bench-fast-queue-throughput-serial-10000;46, only (135, 135) elements.
#   Running analysis for commit 51...
#   Skip bench-fast-queue-throughput-serial-10000;51, only (135, 135) elements.
#   Running analysis for commit 56...
#   Skip bench-fast-queue-throughput-serial-10000;56, only (135, 135) elements.
#   Running analysis for commit 6...
#   Skip bench-fast-queue-throughput-serial-10000;6, only (135, 135) elements.
#   Running analysis for commit 61...
#   Skip bench-fast-queue-throughput-serial-10000;61, only (135, 135) elements.
#   Running analysis for commit 66...
#   Skip bench-fast-queue-throughput-serial-10000;66, only (135, 135) elements.
# Running analysis for benchmark bench-fast-queue-throughput-serial-100000...
#   Running analysis for commit 1...
#   Skip bench-fast-queue-throughput-serial-100000;1, only (90, 90) elements.
#   Running analysis for commit 11...
#   Skip bench-fast-queue-throughput-serial-100000;11, only (90, 90) elements.
#   Running analysis for commit 16...
#   Skip bench-fast-queue-throughput-serial-100000;16, only (90, 90) elements.
#   Running analysis for commit 21...
#   Skip bench-fast-queue-throughput-serial-100000;21, only (90, 90) elements.
#   Running analysis for commit 26...
#   Skip bench-fast-queue-throughput-serial-100000;26, only (90, 90) elements.
#   Running analysis for commit 31...
#   Skip bench-fast-queue-throughput-serial-100000;31, only (90, 90) elements.
#   Running analysis for commit 36...
#   Skip bench-fast-queue-throughput-serial-100000;36, only (90, 90) elements.
#   Running analysis for commit 41...
#   Skip bench-fast-queue-throughput-serial-100000;41, only (90, 90) elements.
#   Running analysis for commit 46...
#   Skip bench-fast-queue-throughput-serial-100000;46, only (90, 90) elements.
#   Running analysis for commit 51...
#   Skip bench-fast-queue-throughput-serial-100000;51, only (90, 90) elements.
#   Running analysis for commit 56...
#   Skip bench-fast-queue-throughput-serial-100000;56, only (90, 90) elements.
#   Running analysis for commit 6...
#   Skip bench-fast-queue-throughput-serial-100000;6, only (90, 90) elements.
#   Running analysis for commit 61...
#   Skip bench-fast-queue-throughput-serial-100000;61, only (90, 90) elements.
#   Running analysis for commit 66...
#   Skip bench-fast-queue-throughput-serial-100000;66, only (90, 90) elements.
# Running analysis for benchmark bench-fast-queue-throughput-serial-1000000...
#   Already analyzed, skip.
# Running analysis for benchmark bench-index-db-add-tsids...
#   Already analyzed, skip.
# Running analysis for benchmark bench-index-db-get-tsids...
#   Already analyzed, skip.

# %%
print("Done.")
# Out:
# Done.
