# %% [markdown]
# # Analyze Microbenchmarks
#
# Load, parse and analyze microbenchmarks.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import glob
import os
import json

# %%
commitTable = pd.read_csv('commitTable.csv', sep=';', index_col=0)
commitTable = commitTable.drop(0)
commitTable = commitTable[::-5][::-1]
commitTable.to_csv('commitTable5.csv', sep=';')

# %% [markdown]
# ## Preprocess and clean data

# %%
results_file = glob.glob(os.path.join("resultsMicro", "runtest", "0",  "microbenchResults.csv"))     # advisable to use os.path.join as this makes concatenation OS independent

df = pd.read_csv(results_file[0], names=["run", "Baseline", "path", "name", "system", "invocations", "runtime"], sep=';')


df.loc[(df["name"] == "16") & (df["runtime"] < 1500), "name"] = "BenchmarkStorageAddRows1"
df.loc[(df["name"] == "16") & (df["runtime"] < 10000), "name"] = "BenchmarkStorageAddRows2"
df.loc[(df["name"] == "16") & (df["runtime"] < 100000), "name"] = "BenchmarkStorageAddRows3"
df.loc[(df["name"] == "16"), "name"] = "BenchmarkStorageAddRows4"

df = df[["run", "path", "name", "system", "runtime"]]

df1 = df[df["system"] == 1]
df2 = df[df["system"] == 2]
df1.head(10)
# Out:
#       run                                               path  \
# 6   0-0-0  /lib/protoparser/csvimport/parser_timing_test....
# 7   0-0-0  /lib/protoparser/csvimport/parser_timing_test....
# 8   0-0-0  /lib/protoparser/csvimport/parser_timing_test....
# 9   0-0-0  /lib/protoparser/csvimport/parser_timing_test....
# 10  0-0-0  /lib/protoparser/csvimport/parser_timing_test....
# 11  0-0-0  /lib/protoparser/csvimport/parser_timing_test....
# 18  0-0-0  /lib/storage/index_db_timing_test.go/Benchmark...
# 19  0-0-0  /lib/storage/index_db_timing_test.go/Benchmark...
# 20  0-0-0  /lib/storage/index_db_timing_test.go/Benchmark...
# 21  0-0-0  /lib/storage/index_db_timing_test.go/Benchmark...
#
#                           name  system     runtime
# 6     BenchmarkRowsUnmarshal-2       1       838.0
# 7     BenchmarkRowsUnmarshal-2       1       843.9
# 8     BenchmarkRowsUnmarshal-2       1       836.0
# 9     BenchmarkRowsUnmarshal-2       1       836.1
# 10    BenchmarkRowsUnmarshal-2       1       834.9
# 11    BenchmarkRowsUnmarshal-2       1       835.3
# 18  "bench-index-db-get-tsids"       1   7066595.0
# 19  "bench-index-db-get-tsids"       1  10174882.0
# 20  "bench-index-db-get-tsids"       1  10034955.0
# 21  "bench-index-db-get-tsids"       1   6931156.0

# %%
def aggregate_values(df):
    df_aggregated = pd.DataFrame(columns = ['path', 'name', 'median', 'mean', 'rel_std'])

    for name, group in df.groupby(["path", "name"]):
        df_tmp = df[(df["path"] == name[0]) & (df["name"] == name[1])]
        if df_tmp.shape[0] == 30:
            df_aggregated = df_aggregated.append({'path' : name[0], 
                                                    'name' : name[1], 
                                                    'median' : df_tmp["runtime"].median(), 
                                                    'mean' : df_tmp["runtime"].mean(), 
                                                    'rel_std' : 100 * df_tmp["runtime"].std() / df_tmp["runtime"].mean()
                                                   }, 
                    ignore_index = True)

    return df_aggregated

# %%
df1_aggregated = aggregate_values(df1)

# %%
df2_aggregated = aggregate_values(df2)

# %%
df1_aggregated[df1_aggregated['rel_std']>5]
# Out:
#                                                   path  \
# 9    /lib/decimal/decimal_timing_test.go/BenchmarkF...
# 67   /lib/storage/index_db_timing_test.go/Benchmark...
# 68   /lib/storage/index_db_timing_test.go/Benchmark...
# 92   /lib/uint64set/uint64set_timing_test.go/Benchm...
# 93   /lib/uint64set/uint64set_timing_test.go/Benchm...
# 97   /lib/uint64set/uint64set_timing_test.go/Benchm...
# 102  /lib/uint64set/uint64set_timing_test.go/Benchm...
# 103  /lib/uint64set/uint64set_timing_test.go/Benchm...
# 114  /lib/uint64set/uint64set_timing_test.go/Benchm...
# 138  /lib/uint64set/uint64set_timing_test.go/Benchm...
# 144  /lib/uint64set/uint64set_timing_test.go/Benchm...
# 145  /lib/uint64set/uint64set_timing_test.go/Benchm...
# 146  /lib/uint64set/uint64set_timing_test.go/Benchm...
# 147  /lib/uint64set/uint64set_timing_test.go/Benchm...
# 148  /lib/uint64set/uint64set_timing_test.go/Benchm...
# 155  /lib/uint64set/uint64set_timing_test.go/Benchm...
# 156  /lib/uint64set/uint64set_timing_test.go/Benchm...
# 159  /lib/uint64set/uint64set_timing_test.go/Benchm...
# 160  /lib/uint64set/uint64set_timing_test.go/Benchm...
# 165  /lib/uint64set/uint64set_timing_test.go/Benchm...
# 166  /lib/uint64set/uint64set_timing_test.go/Benchm...
#
#                                                 name        median  \
# 9                             BenchmarkFromFloat/0-2  3.386500e+00
# 67                        "bench-index-db-add-tsids"  6.939450e+06
# 68                        "bench-index-db-get-tsids"  8.747878e+06
# 92       BenchmarkIntersectFullOverlap/items_10000-2  6.115000e+03
# 93      BenchmarkIntersectFullOverlap/items_100000-2  1.763900e+04
# 97         BenchmarkIntersectNoOverlap/items_10000-2  5.936000e+03
# 102   BenchmarkIntersectPartialOverlap/items_10000-2  6.098000e+03
# 103  BenchmarkIntersectPartialOverlap/items_100000-2  1.470750e+04
# 114      BenchmarkMapAddRandomLastBits/lastBits_32-2  5.569072e+06
# 138      BenchmarkSetAddRandomLastBits/lastBits_32-2  8.207494e+06
# 144                  BenchmarkSetHasHit/items_1000-2  7.932000e+03
# 145                 BenchmarkSetHasHit/items_10000-2  7.913450e+04
# 146                BenchmarkSetHasHit/items_100000-2  9.709785e+05
# 147               BenchmarkSetHasHit/items_1000000-2  1.171769e+07
# 148              BenchmarkSetHasHit/items_10000000-2  1.128033e+08
# 155          BenchmarkUnionFullOverlap/items_10000-2  5.960500e+03
# 156         BenchmarkUnionFullOverlap/items_100000-2  1.714650e+04
# 159             BenchmarkUnionNoOverlap/items_1000-2  5.895000e+03
# 160            BenchmarkUnionNoOverlap/items_10000-2  5.985000e+03
# 165       BenchmarkUnionPartialOverlap/items_10000-2  6.007500e+03
# 166      BenchmarkUnionPartialOverlap/items_100000-2  1.600400e+04
#
#              mean     rel_std
# 9    3.548300e+00    5.261962
# 67   8.120782e+06   22.229582
# 68   8.711584e+06    8.463439
# 92   8.230767e+03   33.487537
# 93   1.667137e+04   13.770035
# 97   6.227600e+03   10.202525
# 102  6.314500e+03    8.983047
# 103  1.436787e+04    5.387355
# 114  5.626655e+06    5.659037
# 138  1.728439e+07  128.764607
# 144  8.069433e+03    5.105498
# 145  8.644767e+04   12.239269
# 146  9.699873e+05    5.388760
# 147  1.165480e+07    7.093412
# 148  1.094886e+08    9.511278
# 155  7.059133e+03   32.314446
# 156  1.518827e+04   17.769139
# 159  6.889500e+03   30.159282
# 160  6.868100e+03   26.391124
# 165  6.888867e+03   26.710410
# 166  1.729577e+04   12.927005

# %%
rel_speedup = (df1_aggregated['median'] / df2_aggregated['median'] - 1) * 100
rel_speedup[rel_speedup > 5]
# Out:
# 103    53.458890
# 148     7.814112
# 151     5.349477
# 156    40.292096
# 157     7.209760
# Name: median, dtype: float64

# %%
print(df1_aggregated.loc[105], df2_aggregated.loc[105])
# Out:
# path       /lib/uint64set/uint64set_timing_test.go/Benchm...
# name       BenchmarkIntersectPartialOverlap/items_10000000-2
# median                                              933313.5
# mean                                           934324.633333
# rel_std                                             1.567717
# Name: 105, dtype: object path       /lib/uint64set/uint64set_timing_test.go/Benchm...
# name       BenchmarkIntersectPartialOverlap/items_10000000-2
# median                                              943510.0
# mean                                           938351.333333
# rel_std                                             2.236638
# Name: 105, dtype: object
